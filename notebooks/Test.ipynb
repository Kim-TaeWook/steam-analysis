# %%
import requests
import pandas as pd

def get_all_steam_apps():
    url = "https://api.steampowered.com/ISteamApps/GetAppList/v2/"
    response = requests.get(url)
    app_list = response.json()['applist']['apps']
    df_apps = pd.DataFrame(app_list)
    return df_apps

df_apps = get_all_steam_apps()
df_apps.to_csv("steam_applist.csv", index=False)
df_apps.head()
# Out:
#      appid                           name
# 0  2006441
# 1  2005791
# 2   216938  Pieterw test app76 ( 216938 )
# 3   660010                          test2
# 4   660130                          test3

# %%
import time

def get_app_details(appid):
    url = f"https://store.steampowered.com/api/appdetails?appids={appid}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data[str(appid)]['success']:
            return data[str(appid)]['data']
    return None

# 테스트: 440번은 Team Fortress 2
app_detail = get_app_details(440)
print(app_detail['name'], app_detail['type'], app_detail['release_date']['date'])
# Out:
# Team Fortress 2 game 10. Okt. 2007

# %%
appids = df_apps['appid'].tolist()[:100]  # 우선 100개만 테스트

data_list = []

for appid in appids:
    details = get_app_details(appid)
    if details and details.get('type') == 'game':
        data_list.append({
            'appid': appid,
            'name': details.get('name'),
            'release_date': details.get('release_date', {}).get('date'),
            'is_free': details.get('is_free'),
            'type': details.get('type'),
            'genres': details.get('genres'),
            'price_overview': details.get('price_overview'),
        })
    time.sleep(0.2)  # 서버 부하 방지

df_details = pd.DataFrame(data_list)
df_details.to_csv("steam_app_details_sample.csv", index=False)
df_details.head()
# Out:
#     appid                   name  release_date  is_free  type  \
# 0  835110  America's Retribution  21 Apr, 2018    False  game
# 1  835130            Last Stanza   9 Nov, 2018    False  game
# 2  835040               美少女夏日欢乐!  24 May, 2018    False  game
# 3  834880                Acro FS  23 May, 2018     True  game
# 4  834910                  ATLAS  22 Dec, 2018    False  game
#
#                                               genres  \
# 0  [{'id': '1', 'description': 'Action'}, {'id': ...
# 1  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 2  [{'id': '71', 'description': 'Sexual Content'}...
# 3  [{'id': '28', 'description': 'Simulation'}, {'...
# 4  [{'id': '1', 'description': 'Action'}, {'id': ...
#
#                                       price_overview
# 0  {'currency': 'KRW', 'initial': 440000, 'final'...
# 1  {'currency': 'KRW', 'initial': 890000, 'final'...
# 2  {'currency': 'KRW', 'initial': 198000, 'final'...
# 3                                               None
# 4  {'currency': 'KRW', 'initial': 3100000, 'final...

# %%
df_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   appid           36 non-null     int64
#  1   name            36 non-null     object
#  2   release_date    36 non-null     object
#  3   is_free         36 non-null     bool
#  4   type            36 non-null     object
#  5   genres          36 non-null     object
#  6   price_overview  28 non-null     object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 1.9+ KB

# %%
df_details.describe()
# Out:
#                appid
# count      36.000000
# mean   834419.722222
# std       418.715629
# min    833810.000000
# 25%    833987.500000
# 50%    834430.000000
# 75%    834767.500000
# max    835130.000000

# %%
df_details.dtypes
# Out:
# appid              int64
# name              object
# release_date      object
# is_free             bool
# type              object
# genres            object
# price_overview    object
# dtype: object

# %%
df_details.count()
# Out:
# appid             36
# name              36
# release_date      36
# is_free           36
# type              36
# genres            36
# price_overview    28
# dtype: int64

# %%
df_details
# Out:
#      appid                                       name     release_date  \
# 0   835110                      America's Retribution     21 Apr, 2018
# 1   835130                                Last Stanza      9 Nov, 2018
# 2   835040                                   美少女夏日欢乐!     24 May, 2018
# 3   834880                                    Acro FS     23 May, 2018
# 4   834910                                      ATLAS     22 Dec, 2018
# 5   834920                  Operation Osama Bin Laden     24 May, 2021
# 6   834930        Bishi and the Alien Slime Invasion!     23 Apr, 2018
# 7   834730                              Crazy Justice      Coming soon
# 8   834740                             Circle Empires      8 Aug, 2018
# 9   834750           Crucible Falls: Together Forever     21 Apr, 2018
# 10  834760                         Robot Wants It All      4 Apr, 2019
# 11  834790                      Eggs: All Guns Broken     11 Sep, 2024
# 12  834800                                  SolSeraph     10 Jul, 2019
# 13  834320  My Mad Road - adventure racing & shooting  To be announced
# 14  834380                                  Cube Zone     15 May, 2018
# 15  834390            King's Heir: Rise to the Throne     31 May, 2018
# 16  834410                         Hacker News Reader     24 May, 2018
# 17  834420               RollingBall: Unlimited World     10 Apr, 2018
# 18  834440                                   NAMELESS     25 Oct, 2018
# 19  834450       Roarr! The Adventures of Rampage Rex      7 Nov, 2018
# 20  834470                                Zima uhodi!     18 Apr, 2018
# 21  834530                              Yakuza Kiwami     19 Feb, 2019
# 22  834580        東方逆妙乱 ~ Ephemeral Unnatural Balance     16 Aug, 2019
# 23  833810               Extreme Formula Championship     11 May, 2018
# 24  833820                            Mountain Racing     15 May, 2018
# 25  833870                    The Unbreakable Gumball
# 26  833910                                Overchunked     12 Apr, 2018
# 27  833920                               Meme Machine     22 Jun, 2018
# 28  833940                                Vertigo FPS     27 Jun, 2018
# 29  833950                                Risk System     13 May, 2019
# 30  833960                              Mr. Grayscale      Coming soon
# 31  833980                                       Dave     30 Nov, 2018
# 32  833990                     Stonewall Penitentiary     13 May, 2018
# 33  834000                    Cross Country Skiing VR     12 Apr, 2018
# 34  834030                                Slamdunk VR     23 Apr, 2018
# 35  834050                        SixGenerals | 六小将传说     17 May, 2018
#
#     is_free  type                                             genres  \
# 0     False  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 1     False  game  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 2     False  game  [{'id': '71', 'description': 'Sexual Content'}...
# 3      True  game  [{'id': '28', 'description': 'Simulation'}, {'...
# 4     False  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 5     False  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 6      True  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 7      True  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 8     False  game  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 9     False  game         [{'id': '25', 'description': 'Adventure'}]
# 10    False  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 11    False  game  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 12    False  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 13    False  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 14    False  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 15    False  game  [{'id': '25', 'description': 'Adventure'}, {'i...
# 16     True  game  [{'id': '54', 'description': 'Education'}, {'i...
# 17    False  game             [{'id': '23', 'description': 'Indie'}]
# 18    False  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 19    False  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 20    False  game  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 21    False  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 22    False  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 23    False  game  [{'id': '9', 'description': 'Racing'}, {'id': ...
# 24    False  game  [{'id': '25', 'description': 'Adventure'}, {'i...
# 25    False  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 26    False  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 27    False  game  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 28    False  game  [{'id': '73', 'description': 'Violent'}, {'id'...
# 29    False  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 30    False  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 31    False  game  [{'id': '25', 'description': 'Adventure'}, {'i...
# 32    False  game  [{'id': '25', 'description': 'Adventure'}, {'i...
# 33     True  game  [{'id': '9', 'description': 'Racing'}, {'id': ...
# 34    False  game  [{'id': '1', 'description': 'Action'}, {'id': ...
# 35    False  game  [{'id': '4', 'description': 'Casual'}, {'id': ...
#
#                                        price_overview
# 0   {'currency': 'KRW', 'initial': 440000, 'final'...
# 1   {'currency': 'KRW', 'initial': 890000, 'final'...
# 2   {'currency': 'KRW', 'initial': 198000, 'final'...
# 3                                                None
# 4   {'currency': 'KRW', 'initial': 3100000, 'final...
# 5   {'currency': 'KRW', 'initial': 220000, 'final'...
# 6                                                None
# 7                                                None
# 8   {'currency': 'KRW', 'initial': 990000, 'final'...
# 9   {'currency': 'KRW', 'initial': 550000, 'final'...
# 10  {'currency': 'KRW', 'initial': 2150000, 'final...
# 11  {'currency': 'KRW', 'initial': 110000, 'final'...
# 12  {'currency': 'KRW', 'initial': 1600000, 'final...
# 13                                               None
# 14  {'currency': 'KRW', 'initial': 550000, 'final'...
# 15  {'currency': 'KRW', 'initial': 1550000, 'final...
# 16                                               None
# 17  {'currency': 'KRW', 'initial': 110000, 'final'...
# 18  {'currency': 'KRW', 'initial': 750000, 'final'...
# 19  {'currency': 'KRW', 'initial': 340000, 'final'...
# 20  {'currency': 'KRW', 'initial': 110000, 'final'...
# 21  {'currency': 'CAD', 'initial': 2999, 'final': ...
# 22  {'currency': 'KRW', 'initial': 1050000, 'final...
# 23  {'currency': 'KRW', 'initial': 750000, 'final'...
# 24  {'currency': 'KRW', 'initial': 550000, 'final'...
# 25                                               None
# 26  {'currency': 'KRW', 'initial': 220000, 'final'...
# 27  {'currency': 'KRW', 'initial': 560000, 'final'...
# 28  {'currency': 'KRW', 'initial': 550000, 'final'...
# 29  {'currency': 'KRW', 'initial': 1050000, 'final...
# 30                                               None
# 31  {'currency': 'KRW', 'initial': 440000, 'final'...
# 32  {'currency': 'KRW', 'initial': 1250000, 'final...
# 33                                               None
# 34  {'currency': 'KRW', 'initial': 1850000, 'final...
# 35  {'currency': 'KRW', 'initial': 1050000, 'final...

# %%
import requests
import pandas as pd
import time

def get_app_details(appid):
    url = f"https://store.steampowered.com/api/appdetails?appids={appid}"
    try:
        response = requests.get(url, timeout=5)
        if response.status_code == 200:
            data = response.json()
            if data.get(str(appid), {}).get('success'):
                return data[str(appid)]['data']
    except Exception as e:
        print(f"[ERROR] appid {appid} - {e}")
    return None

def collect_game_data(df_apps, target_count=1000, save_interval=50):
    collected = []
    appids = df_apps['appid'].tolist()
    checked = 0

    for appid in appids:
        details = get_app_details(appid)
        checked += 1

        if details and details.get('type') == 'game':
            collected.append({
                'appid': appid,
                'name': details.get('name'),
                'release_date': details.get('release_date', {}).get('date'),
                'is_free': details.get('is_free'),
                'type': details.get('type'),
                'genres': details.get('genres'),
                'price_overview': details.get('price_overview'),
            })

            # 중간 저장
            if len(collected) % save_interval == 0:
                df_partial = pd.DataFrame(collected)
                df_partial.to_csv("steam_game_data_partial.csv", index=False)
                print(f"[INFO] Collected {len(collected)} valid games after checking {checked} apps")

            # 목표 수량 도달
            if len(collected) >= target_count:
                break

        # 요청 속도 제한
        time.sleep(0.2)

    df_result = pd.DataFrame(collected)
    df_result.to_csv("steam_game_data_final.csv", index=False)
    print(f"[DONE] Final saved: {len(df_result)} games from {checked} appids checked")
    return df_result

# %%
# 예: 목표 1000개, 50개마다 저장
df_result = collect_game_data(df_apps, target_count=1000, save_interval=50)

# 수집 데이터 미리보기
df_result.head()
# Out:
# [INFO] Collected 50 valid games after checking 120 apps
# [INFO] Collected 100 valid games after checking 185 apps
# [INFO] Collected 150 valid games after checking 677 apps
# [INFO] Collected 200 valid games after checking 770 apps
# [INFO] Collected 250 valid games after checking 845 apps
# [INFO] Collected 300 valid games after checking 1228 apps
# [INFO] Collected 350 valid games after checking 1301 apps
# [INFO] Collected 400 valid games after checking 1396 apps
# [INFO] Collected 450 valid games after checking 1861 apps
# [INFO] Collected 500 valid games after checking 1945 apps
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 2
#       1 # 예: 목표 1000개, 50개마다 저장
# ----> 2 df_result = collect_game_data(df_apps, target_count=1000, save_interval=50)
#       4 # 수집 데이터 미리보기
#       5 df_result.head()
#
# Cell In[23], line 48, in collect_game_data(df_apps, target_count, save_interval)
#      45             break
#      47     # 요청 속도 제한
# ---> 48     time.sleep(0.2)
#      50 df_result = pd.DataFrame(collected)
#      51 df_result.to_csv("steam_game_data_final.csv", index=False)
#
# KeyboardInterrupt:

# %%
df_result.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df_result.head()
#
# NameError: name 'df_result' is not defined
